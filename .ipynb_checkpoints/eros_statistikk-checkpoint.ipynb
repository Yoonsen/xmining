# %% [markdown]
# # Notebook for erosmining

# %% [markdown]
# Start med å importere de kommandoene som trengs fra nbtext

# %%
import module_update
import nbtext as nb

# %matplotlib inline
# Out:
# Updated file nbtext.py
# Updated file nbpictures.py

# %%
urns = nb.get_urns_from_docx('./Materiale erotisk litteratur 1945-1970 liste 27.09.18.docx')
print('Antall URNer: ', len(urns))

# %%
# rekonstruerer metadata for URN-ene
meta = [nb.metadata(urn) for urn in urns]

# %% [markdown]
# ## Konkordanser
#
# Bare kopier cellen og kjør flere ganger. Det tar noen sekunder, i og med at korpuset er såpass stort. Effektivisering er under planlegging.

# %%
nb.get_urnkonk('flerret', {'urns':urns, 'before':12, 'after':12, 'size':2})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014102308087' target='_blank' style='text-decoration:none'>Farlige år, Nygaard, Leo, 1961</a>
#                 </td>
#                 <td>med den ledige armen . Det svartnet alt. Han trodde brystet var</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>. . , .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013041908081' target='_blank' style='text-decoration:none'>Med kaldt blod, Spillane, Mickey, 1967</a>
#                 </td>
#                 <td>der og lurte på hva jeg skulle gjøre , da et lyn</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>natten i stykker .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007051604017' target='_blank' style='text-decoration:none'>Helten på eselryggen, Bulatovič, Miodrag, 1966</a>
#                 </td>
#                 <td>i bregnene , så Antonio hvordan de rev over ende flaggstangen og</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>iBtvkker det italienske flagget med kniver , negler og tenner . Men</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011070805079' target='_blank' style='text-decoration:none'>Lady Chatterleys elsker, Lawrence, D.H., 1952</a>
#                 </td>
#                 <td>Lyskasterne</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>mørket med sitt skjær .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014102308087' target='_blank' style='text-decoration:none'>Farlige år, Nygaard, Leo, 1961</a>
#                 </td>
#                 <td>med den ledige armen . Det svartnet alt. Han trodde brystet var</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>. . , .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013042408063' target='_blank' style='text-decoration:none'>Riflen og spydet, Croudace, Glynn, 1969</a>
#                 </td>
#                 <td>protestere , hadde han tatt fatt i halsåpningen med begge hender og</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>serken helt ned .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013042408063' target='_blank' style='text-decoration:none'>Riflen og spydet, Croudace, Glynn, 1969</a>
#                 </td>
#                 <td>Piet Viljoen , som ledet Tonys patrulje . Grovsmedens venstre kinn var</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>åpent helt inn til benet , og det buskete skjegget hans var</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007080801076' target='_blank' style='text-decoration:none'>Sort messe, Bolstad, Øivind, 1970</a>
#                 </td>
#                 <td>fikk hun lukket døren og vaklet tilbake til sitt eget rom og</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>av seg nattkjolen og begynte å stryke seg over brystene , slik</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007080801076' target='_blank' style='text-decoration:none'>Sort messe, Bolstad, Øivind, 1970</a>
#                 </td>
#                 <td>— takk i evighet — evighet . . . Han slo og</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>kvistene til seg . Stemmen steg :</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007080801076' target='_blank' style='text-decoration:none'>Sort messe, Bolstad, Øivind, 1970</a>
#                 </td>
#                 <td>— Du har drukket dem for meg , sa han ondskapsfullt og</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>systematisk et lommetørkle i filler .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016101948066' target='_blank' style='text-decoration:none'>Jeg slipper deg aldri, Nichols, Fan, 1958</a>
#                 </td>
#                 <td>gjort mot ham . Det</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>opp et sår inne i ham , og det sved og smertet</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013041908041' target='_blank' style='text-decoration:none'>Het sommer, MacDonald, John D., 1958</a>
#                 </td>
#                 <td>rallet og var tomme , uten syn . Munnen hennes var liksom</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>. Sollyset virket som gult metall på strupen hennes . Han hadde</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014032808013' target='_blank' style='text-decoration:none'>Heretter følger jeg deg helt hjem, Askildsen, Kjell, 1953</a>
#                 </td>
#                 <td>av ensfarget papir . Gult , nærmest . I hjørnene var papiret</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>, og for å bøte på skaden var det puttet inn røde</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016112148515' target='_blank' style='text-decoration:none'>Avsporet, Ellson, Hal, 1960</a>
#                 </td>
#                 <td>over ham samtidig , svor , sparket , slo . En knyttneve</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>hans lepper , et spark gjorde at han mistet pusten .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016112148515' target='_blank' style='text-decoration:none'>Avsporet, Ellson, Hal, 1960</a>
#                 </td>
#                 <td>over ham samtidig , svor , sparket , slo . En knyttneve</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>hans lepper , et spark gjorde at han mistet pusten .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011110308063' target='_blank' style='text-decoration:none'>To døgn, Stigen, Terje, 1950</a>
#                 </td>
#                 <td>grønt skum . Det siste jeg så var den stygge snuten som</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>opp for et gjerde av hvite , spisse støttenner . — Sa</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011110308063' target='_blank' style='text-decoration:none'>To døgn, Stigen, Terje, 1950</a>
#                 </td>
#                 <td>Et par lynglimt</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>plutselig mørket . Tordenbraket hamret dempet på veggene rundt ham — en</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014102308087' target='_blank' style='text-decoration:none'>Farlige år, Nygaard, Leo, 1961</a>
#                 </td>
#                 <td>med den ledige armen . Det svartnet alt. Han trodde brystet var</td>
#                 <td>flerret</td>
#                 <td style='text-align:left'>. . , .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='h

# %% [markdown]
# ## Næranalyse av en enkelt tekst

# %% [markdown]
# En eller flere ordlister for forskjellige formål.

# %%
# Eksempel fra noen av ordene nevnt i den her sammenhengen
words = """brystene brystet låret lår lemmet stønnet stønne stønner leppene rev rive river flerret flerre flerrer
snerret snerre snerrer kjønnet grotten
rope roper ropte skrek skrike skriker presset kikket kikke kikker stirret stirre stirrer""".split()

# %%
gladord = nb.relaterte_ord('glad, munter')

# %% [markdown]
# # Grafanalyse av ordene i en enkelt tekst
#
# Her får du en graf som viser samforekomsten av ord. Det lages en kobling om ordene står i samme avsnitt. Det går også fint å lime en URN fra word-dokumentet.

# %%
print(nb.metadata(urns[30]))
# Out:
# [[2013042408063, 'Croudace, Glynn', 1969, 'Riflen og spydet', 'Bladkompaniet', 'nob', 'eng']]

# %%
G = nb.make_network(urns[30], wordbag=words)

# %%
nb.draw_graph_centrality(G, fontsize=12, k=0.6)
# Out:
# True

# %%
nb.central_betweenness_characters(G)
# Out:
# [('brystet', 0.2972222222222222),
#  ('presset', 0.2403133903133903),
#  ('skrek', 0.13376068376068373),
#  ('leppene', 0.07934472934472935),
#  ('stirret', 0.07649572649572649),
#  ('kikket', 0.06801994301994302),
#  ('lår', 0.03098290598290598),
#  ('brystene', 0.005128205128205128),
#  ('ropte', 0.00462962962962963),
#  ('låret', 0.0)]

# %% [markdown]
# # Vekstdiagram
#
# For vekstdiagram brukes kommandoen nb.vekstdiagram().plot(). Input til vekstdiagram er en URN sammen med en liste av ord.

# %%
print(nb.metadata(urns[30]))
nb.vekstdiagram(urns[30], {'words': words, 'window':5000}).plot(figsize=(15,5))
# Out:
# [[2013042408063, 'Croudace, Glynn', 1969, 'Riflen og spydet', 'Bladkompaniet', 'nob', 'eng']]

# %%
nb.plot_sammen_vekst(urns[30],[words, gladord]).plot()

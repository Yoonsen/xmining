# %% [markdown]
# #### Paracode

# %% [markdown]
# Laster ned moduler og filer, `module_update`, `nbtext` og `graph_networkx_louvain`

# %%
! curl -s "https://raw.githubusercontent.com/Yoonsen/Modules/master/module_update.py" > "module_update.py"

# %%
from module_update import update, css, code_toggle, printmd
update('nbtext', overwrite=True)
update('graph_networkx_louvain', overwrite=True)
# Out:
# Updated file `C:\Users\larsj\Documents\GitHub\xmining\nbtext.py`
# Updated file `C:\Users\larsj\Documents\GitHub\xmining\graph_networkx_louvain.py`

# %% [markdown]
# ## Her er noen tilpassede funksjoner

# %%
import requests
def normalize_corpus_dataframe(df):
    colsums = df.sum()
    for x in colsums.index:
        #print(x)
        df[x] = df[x].fillna(0)/colsums[x]
    return True

def urn_coll(word, urns=[], after=5, before=5, limit=1000):
    """Find collocations for a word in a set of books represented by URNs.
    Compute a collocation across the books, or pr. book. Both result in a one column dataframe representing
    the collocations.
    """
    
    if isinstance(urns[0], list):  # urns assumed to be list of list with urn-serial as first element
        urns = [u[0] for u in urns]
    
    r = requests.post("https://api.nb.no/ngram/urncoll", json={'word':word, 'urns':urns, 
                                                                   'after':after, 'before':before, 'limit':limit})
    res = pd.DataFrame.from_dict(r.json(), orient='index')
    if not res.empty:
        res = res.sort_values(by=res.columns[0], ascending = False)
    return res

def urn_coll_pr(word, urns=[], after=5, before=5, limit=1000):
        coll = dict()
        for urn in urns:
            cll = urn_coll(word, [urn], after=after, before=before, limit=limit)
            if not cll.empty:
                coll[urn] = cll
        colls = pd.DataFrame.from_dict(coll, orient='index' ).fillna(0)
        normalize_corpus_dataframe(colls)
        scoll = colls.mean(axis=1)
        res = pd.DataFrame(scoll.sort_values(ascending=False))

# %% [markdown]
# Aktiver eller fjern `css`

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# Importer moduler

# %%
import nbtext as nb
import graph_networkx_louvain as gnl
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Slår av advarsler fra IPython

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Notebook for erosmining

# %% [markdown]
# Pass på referansene til URN-definisjonene

# %%
urns = nb.get_urns_from_docx('../Materiale erotisk litteratur 1945-1970 liste 27.09.18.docx')
print('Antall URNer: ', len(urns), urns[:5])
# Out:
# Antall URNer:  456 ['2015090129001', '2011112308125', '2012021608164', '2016111748512', '2010111706020']

# %% [markdown]
# Det kvinnelige materialet

# %%
fem_urns = nb.get_urns_from_docx('../Kvinner Materiale erotisk litteratur 1945-1970 liste  08.02.19.docx')
print("Antall: ", len(fem_urns))
# Out:
# Antall:  39

# %%
# rekonstruerer metadata for URN-ene
meta = [nb.metadata(u) for u in urns]

# %% [markdown]
# ### En hurtigversjon av konkordansekommando
#
# Skriv `konk('bryst')` for å undersøke korpuset. For å se blant URN-er fra kvinner, skriv `konk('bryst', urns=fem_urns)`.
#
# I neste celle defineres kommandoen, med eksempler etter der igjen.

# %%
konk = lambda word, urns = urns, before = 8, after = 4, size = 2: nb.get_urnkonk(word, {'urns':nb.refine_urn(urns,{'words':[word]} )[:30], 'before':before, 'after':after, 'size':size})

# %% [markdown]
# ## Konkordanser
#
# Bare kopier cellen og kjør flere ganger. Det tar noen sekunder, i og med at korpuset er såpass stort. Effektivisering er under planlegging.

# %%
konk('blusen', urns=fem_urns)
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007072501029?searchText=blusen' target='_blank' style='text-decoration:none'>Gråt elskede mann, Vik, Bjørg, 1970</a>
#                 </td>
#                 <td>under det tynne mattglinsende stoffet i den løstsittende</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>, når hun bøyer</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007072501029?searchText=blusen' target='_blank' style='text-decoration:none'>Gråt elskede mann, Vik, Bjørg, 1970</a>
#                 </td>
#                 <td>og hjelpeløse da hun begynner å kneppe opp</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>og munnen halvåpen ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007072501029?searchText=blusen' target='_blank' style='text-decoration:none'>Gråt elskede mann, Vik, Bjørg, 1970</a>
#                 </td>
#                 <td>hodet og kysser begge fredsommelig før han lukker</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>og legger hodet i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007072501029?searchText=blusen' target='_blank' style='text-decoration:none'>Gråt elskede mann, Vik, Bjørg, 1970</a>
#                 </td>
#                 <td>at hun ikke har stelt håret , at</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>er halvskitten og med</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013042508013?searchText=blusen' target='_blank' style='text-decoration:none'>Livets flamme, Trolle, Elsa af, 1953</a>
#                 </td>
#                 <td>som en fiskestim . De stakk hånden innenfor</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>hennes , eller klappet</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013052908048?searchText=blusen' target='_blank' style='text-decoration:none'>Afrikas blod, Croudace, Glynn, 1969</a>
#                 </td>
#                 <td>hånden hans , og han stakk den innenfor</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>og tok rundt brystenes</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015060508198?searchText=blusen' target='_blank' style='text-decoration:none'>Frøknene von Pahlen, Krusenstjerna, Agnes von, 1953</a>
#                 </td>
#                 <td>var vel atten . Og du knappet opp</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>din for meg .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015060508198?searchText=blusen' target='_blank' style='text-decoration:none'>Frøknene von Pahlen, Krusenstjerna, Agnes von, 1953</a>
#                 </td>
#                 <td>hjalp ham den gang og knappet seiv opp</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>med et smil og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015060508198?searchText=blusen' target='_blank' style='text-decoration:none'>Frøknene von Pahlen, Krusenstjerna, Agnes von, 1953</a>
#                 </td>
#                 <td>Du knapper bare opp</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>, sa han og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015060508198?searchText=blusen' target='_blank' style='text-decoration:none'>Frøknene von Pahlen, Krusenstjerna, Agnes von, 1953</a>
#                 </td>
#                 <td>der og så på at hun knappet igjen</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>over de faste ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007050401037?searchText=blusen' target='_blank' style='text-decoration:none'>Det grådige hjerte, Vik, Bjørg, 1968</a>
#                 </td>
#                 <td>at hun er usikker og at den hvite</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>er gått i sømmen</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013112808193?searchText=blusen' target='_blank' style='text-decoration:none'>Tørst, Tengroth, Birgit, 1949</a>
#                 </td>
#                 <td>voksne kvinnfolk, sa jeg og spente brystene under</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>. Du må vel</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007051604048?searchText=blusen' target='_blank' style='text-decoration:none'>Babyhip, Welles, Patricia, 1968</a>
#                 </td>
#                 <td>raskt forkleet av seg igjen og kneppet opp</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>. « Jeg tror</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007051604048?searchText=blusen' target='_blank' style='text-decoration:none'>Babyhip, Welles, Patricia, 1968</a>
#                 </td>
#                 <td>. « Jeg tror det er bedre uten</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>. » Hun hang</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007051604048?searchText=blusen' target='_blank' style='text-decoration:none'>Babyhip, Welles, Patricia, 1968</a>
#                 </td>
#                 <td>er bedre uten blusen . » Hun hang</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>på en knagg på</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015060508197?searchText=blusen' target='_blank' style='text-decoration:none'>Frøknene von Pahlen, Krusenstjerna, Agnes von, 1953</a>
#                 </td>
#                 <td>å tørke dem vekk ned på den lyse</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015060508197?searchText=blusen' target='_blank' style='text-decoration:none'>Frøknene von Pahlen, Krusenstjerna, Agnes von, 1953</a>
#                 </td>
#                 <td>Elsa hadde glemt å knappe en knapp i</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>og jeg sa det</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015060508197?searchText=blusen' target='_blank' style='text-decoration:none'>Frøknene von Pahlen, Krusenstjerna, Agnes von, 1953</a>
#                 </td>
#                 <td>av seg kåpen . Smilende hektet hun opp</td>
#                 <td>blusen</td>
#                 <td style='text-align:left'>sin og tok av</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015060508197?searchText=blusen' target='_blank' style='text-decoration:none'>Frøknene von Pahlen, Krusenstjerna, Agnes von, 1953</a>
#                 </td>
#                 <td>silende nedover haken og ned pa den hvite</td>
#                 <td>blusen</td>

# %% [markdown]
# ## Næranalyse av en enkelt tekst

# %% [markdown]
# En eller flere ordlister for forskjellige formål.

# %%
# Eksempel fra noen av ordene nevnt i den her sammenhengen
words = """brystene brystet låret lår lemmet presset presse presser stønnet stønne stønner leppene rev rive river flerret flerre flerrer
snerret snerre snerrer kjønnet grotten stivt slapt slapp stive stiv
 kikket kikke kikker stirret stirre stirrer""".split()

# %%
omsorg = """hverandre holdt ømt varsomt følelse følte nærhet nærheten""".split()

# %%
gladord = nb.relaterte_ord('glad, munter')

# %% [markdown]
# # Grafanalyse av ordene i en enkelt tekst
#
# Her får du en graf som viser samforekomsten av ord. Det lages en kobling om ordene står i samme avsnitt. Det går også fint å lime en URN fra word-dokumentet.

# %%
print(nb.metadata(urns[30]))
# Out:
# [[2013042408063, 'Croudace, Glynn', 1969, 'Riflen og spydet', 'Bladkompaniet', 'nob', 'eng']]

# %%
G = nb.make_network(urns[30], wordbag=words+omsorg)

# %%
gnl.show_graph(G);

# %%
def collcomp(df_column, comp, exp = 1):
    """df_column is a column in a dataframe - a series, while comp is also a series object"""
    res = (df_column**exp/comp).sort_values(ascending=False)
    return res

# %%
import networkx as nx
def make_urn_collocation_graph(target_word, urns, comparo, top = 15, before = 4, after = 4, limit = 1000, exp=1):
        """Make a cascaded network of collocations"""

        firstcoll = urn_coll(target_word, urns, before=before, after=after, limit=limit)
        normalize_corpus_dataframe(firstcoll)
        coll = collcomp(firstcoll[0], comparo, exp = exp)
        target_graf = dict()
        edges = []
        for word in coll[:top].index:
            edges.append((target_word, word))
            if word.isalpha():
                twocoll = urn_coll(word, urns, before=before, after=after,  limit=limit)
                normalize_corpus_dataframe(twocoll)
                coll2 = collcomp(twocoll[0], comparo, exp = exp)
                for w in collcomp(coll2, comparo, exp = exp)[:top].index:
                    if w.isalpha():
                        edges.append((word, w)) 

        target_graph = nx.Graph()
        target_graph.add_edges_from(edges)
        return target_graph

# %% [markdown]
# ### Kommando for å lage ordsky av en kollokasjon

# %%
collcloud = lambda x: nb.cloud(nb.frame(x/x.sum()))

# %% [markdown]
# ### Kommandoer for ordskyer og grafer
#
# Se eksemplene under.

# %%
# noen dictionary-objekter som holder dataene, du slipper å lage nye variable for hver gang
# totalen må være laget, men den er med i initialiseringen av notebooken,sammen med URNene. Se øverst.

Gf = dict()
Colls = dict()

def kollmaker_graph(word, urns, top = 20, before = 5, after = 5, graphdict = Gf, comparo = tot, exp = 1):
    graphdict[word] = make_urn_collocation_graph(word, urns, comparo, top = top, before=before, after=after, exp=1) 
    return True

def kollmaker(word, urns, before = 5, after = 5, colldict = Colls, comparo = tot, exp = 1):
    coll = urn_coll(word, urns, before=before, after=after)
    normalize_corpus_dataframe(coll)
    colldict[word] = collcomp(coll[0], comparo, exp=exp)
    return True

# %%
kollmaker('blusen', urns)
# Out:
# True

# %%
kollmaker('lemmet', urns)
# Out:
# True

# %%
kollmaker_graph('blusen', urns, top=30)
# Out:
# True

# %%
kollmaker_graph('lemmet', urns, top=30 )
# Out:
# True

# %%
Colls.keys()
# Out:
# dict_keys(['lemmet', 'kjønnet', 'musa', 'fitta', 'kuken', 'blusen', 'strittet'])

# %%
collcloud(nb.frame(Colls['lemmet'][:15]))

# %%
gnl.show_graph(gnl.cutdown(Gf['blusen']))

# %%
gnl.show_cliques(Gf['blusen'])
# Out:
# (3, 1) halvåpne, blusen, Belle, vrengte
#
# (3, 2) kjappe, undertøyet, gjennomvåt, brystvortene, vugget, sandaler, skjørt, Fingrene, blusen, brystene, svulmende, brodert, Svetten, duvet, krøllete, knapp, fyldige, fomlet, tettsittende, strittet, orten, skjørtet, knappet, bluse, midjen, strømpene, pyjamas, fikset, kraven, svulmet, navlen, kneppet, knappene, Wendy, buksen, sømmen, glattet, knappe, kvikke, stolryggen, ermer
#
# (4, 1) svulmet, blusen, strittet, brystene, brystvortene
#
# (4, 2) skjørt, tettsittende, blusen, bluse, ermer
#
# (4, 3) kneppet, blusen, knappene, buksen, bluse, knapp
#
# (4, 4) fomlet, knappene, knappet, blusen

# %%
gnl.show_community(Gf['blusen'])
# Out:
# 1 smigrende, uinteressert, gjennomvåt, tvinnet, bustete, brystvortene, uryddig, Amalia, hårene, Klærne, svinet, blusen, fotenden, krøllete, sammen,, overså, kjolene, Cecil, sedlene, lappet, dresser, skjeggete, sedler, feminin, folde, kraven, innhegningen, stripete, Wendy, mørkebrune, overkropp, hulket, krøpet, notisbok
#
# 2 skrivemaskinen, dolken, blyg, avmålt, mistenksom, tispe, høylydt, jakker, trettheten, bryteren, Dyret, seilende, Æsj, tørret, frakken, viBe, teten, kappet, Ten, hanskene, barske, krave, pikken, Tåge, lekre, kløften, Fair, skrenten, Peggy, lommelykt, klaring, absurde, lystret, løytnanten, bringen, olen, Ungen, hissige, vesten, rusten, steile, Bolen, buksene, knappet, iF, uopphørlig, låsen, slipset, omveier, iikk, uforklarlige, sikten, gad, lukkes, løselig, kneppet, nanden, Dora, divanen, opptog, knappe, skjorten, skrøpelige, skjortene, lynsnart
#
# 3 barmen, blodårer, Lines, tretoppene, Bh, ullteppe, ungdommelig, notisboken, stimlet, krøller, skubbet, moderlig, fjærene, brakka, håndflaten, buksen, forlovelsen, glattet, Valerie, rynkete, olmt, posene
#
# 4 plaggene, sanselige, øste, Benedikte, forhekset, farvede, knyttneve, snegler, vrengte, servietten, selvbeherskelse, bevisstløse, Kenny, Bloom, trev, orten, Jen, Ovnene, vokterne, hetten, seZ, Dolly, kvikt, vridde, tåkete, cosa
#
# 5 hektene, krage, gear, kelneren, utmattet, nøklene, Temperaturen, Avenue, tidspunkter, kommanderte, sløvt, Mengden, tørker, Fingrene, Elleve, Btod, praktfull, kortene, sømmene, glitrer, klossete, Moore, oppspilt, illevarslende, revnet, forgylte, fordervet, raffinerte, fomlet, skjorta, mynter, håndvesken, dirrende, gnage, lakken, pyjamas, strømpene, stedfortreder, knapper, ape, nedslått, skjellsord, knappene, Cynthia, dragen, telte, uniformen
#
# 6 prøvende, dinglende, lomme, plasere, Joan, lenet, hengte, nervøse, slengt, parfyme, kåpen, slapt, neglene, Ryggen, Taket, klamre, duftet, tørk, Herved, skuffelsen, maven, Værelset, svinget, lent, stolryggen
#
# 7 undertøyet, rusket, beige, stønne, forsert, skuUe, hemninger, ballene, svulmende, elskling, skjørtet, spiddet, klebet, brette, ustøtt, genseren, lirket, flagret, Kathy, Kjæreste, ynket, rikdommer
#
# 8 kjappe, shorts, glidelåsen, japanerne, intelligente, lyseblå, femtiårene, strømper, fløyel, brusende, tøyet, velstelte, lyserød, egoistisk, lue, sandaler, såes, buskete, Phyllis, undertøy, skjørt, trøye, tøfler, iøynefallende, blekt, lunch, sengeteppet, yngling, neide, Baba, klumpete, brodert, bryn, beskyttelsen, gjennomsiktig, barbent, solbriller, saklige, bulter, strammere, tettsittende, utslått, vrikket, rutete, skotsk, Hayes, avslørte, bluse, midjen, antrekk, morsommere, drakt, navlen, forkleet, drakter, respektabel, ermer, drakten, overkroppen, deise, ermene, genser, snipp, Drive, stripet, Kvinnens
#
# 9 lårene, klaser, nattkjolen, sitrende, bøyet, lillefingeren, Musklene, tast, tjukke, Sheila, underdanig, bittesmå, hoven, Clyde, Minnet, brystene, duvet, svaiet, Austria, gynget, kjærtegnet, herligheten, hoftene, fyldige, kjemme, Sina, ordens, fingertuppene, kjenn, kvikke, børste, strittet, innmat, pungen, handflaten, stivhet, vellyst, Fullstendig, favne, torner, overleppen, høydene, skurrende, innbydende, ribbena
#
# 10 Satt, kameler, Daphne, Direktøren, Btirret, nynne, vugget, håndleddet, sammenkrøpet, flaggermus, nynnet, grevinne, spebarn, gamles, dent, hustruer, koffertene, pip, Wind, jammer, frodige, dovent, barm, rytmisk, bruste, brokete, skinnene
#
# 11 fyltes, vorten, idiotiske, selvsikkerhet, ønskene, opphisselsen, hove, nesebor, mave, kjevene, blodårene, lommebok, handledd, tinningene, gnistret, knopper, Bena, hemmelighetsfulle, svamp, Årene, svulmet, Brystet, hæler, elastiske
#
# 12 omfavnelse, sile, peste, silte, dunke, skjød, Vekk, kloa, oste, dansegulvet, omfavner, ørsmå, Svetten, håndflatene, Prøvde, klø, Farlig, virret, ryggraden, Barnabas, dryppet, kilte, hagle, trykkeriet, parkere, skuldrer, piplet, glinset
#
# 13 Casa, diamanter, alibi, kjeltring, Stanley, verktøyet, svime, feite, leppestift, smørbrød, visnet, Neida, Studio, sloppet, efterpå, åssen, letthet, bedøvet, praten, fikset, Åssen, Lurer, dre, Connie, Bladet
#
# 14 druene, lyserøde, vindstille, kvadratiske, frimerker, kott, kjoler, pigment, stim, spede, hektiske, gjennomsiktige, befridde, flekket, fluene, innvollene, halweis, Kain, HOS, vindpust, småfisk, kjempende, delikate, gardinet
#
# 15 liker, greit, paret, Mr, femti, stjålne, studerte, inngående, velvillige, tørre, film, nattbordet, igjennom, tore, henholdsvis, regne, Vibeke, snor, tykk, kyss, lappene, riktignok, nummer, sått, eie, nakken, knute, forat, bryllup, beholde
#
# 16 ela, nvite, Oz, ez, clv, naclcle, Kei, Evnene, clette, Blatt, Bann, Bagt, cle, OFBa, skifer, takene, KaBtet, Bnakket, cler, rner, clem, nennes, lram, oare, Bterk
#
# 17 halvåpne, løftede, sval, adjunkt, lenestolen, røken, vanskelighet, Leppene, kjøkkendøren, rappe, gjengjeldte, øyelokkene, lengselsfullt, sykelige, øyenbryn, urørlige, øyelokk, søvnige, lepper, Tungen, Geoffrey, Evas, tillitsfullt, ség, profilen, smidige, sivet, ydmykt
#
# 18 nederste, Selve, gale, åse, slang, tykke, kjole, rev, føtter, tynn, dreide, ballen, bakover, bitter, sydd, duft, løsnet, lommene, slet, Inn, samler, sting, sømmen, kjolen, fingrene, innerste, hyllet
#
# 19 Syns, Belle, fridag, møblert, lettsindig, Grey, Jerome, flådd, Prince, overdra, makelig, godnatt, Donald, Sadie, gavmild, Syndere, fortrakk, forfremmelse, Dorothy, hamle, overtalte, forlokkende, Cleveland, Marguerite, Hiis, Adjø, fullendt, opprivende, hospitalet
#
# 20 Mare, fyrer, farvet, Zar, Politimesteren, tribunen, desidert, automatisert, forstyrres, hallo, fingret, raskeste, Elskede, prøvelser, Majoren, knapp, elskelig, billetten, surre, Bertil, blinker, lommeboka, pult, maskineri, prøvelse
#
# 21 sammensvergelse, hornet, utstøtte, ballast, håndleddene, småbiter, fredstid, sekkene, granater, foretagendet, kvalmen, pinlige, kjempen, Klen, luker, blodkar, broer, tonefallet, lenker, demningen, sener, uvegerlig, gigantiske, grenseløse, nøtt, sprenge, omsluttet, Pablo, oppløse
#
# 22 forfulgte, dalte, Samtalen, jungelen, djevler, kjerring, vannflaten, strukket, Ariel, rekkverket, flakket, krattet, tvilende, mediet, byrde, Skyggen, tiltar, Piken, Fangen, løsner, brekker, stønner, tipper, tiger, tred, innhyllet, brutalt, forbannede, hede, plenen

# %%
gnl.show_graph(gnl.cutdown(Gf['lemmet']))

# %%
gnl.show_cliques(Gf['lemmet'])
# Out:
# (3, 1) lemmet, stangen, underlivet, stak, navlen, hurtigt
#
# (3, 2) koran, reisning, lianB, skrotten, lielt, anBiktet, Btirret, KaBtet, slapt, Ovnene, magre, noldt, mez, Btvkke, Bmilte, hvelvet, IvB, viBe, blondt, rødlig, Btod, nenneB, kruset, nanden, lram, skuldrer, Evnene, lemmet, cier, Bkritt, KenneB, mørkeblå, loran

# %%
gnl.show_community(Gf['lemmet'])
# Out:
# 1 nan3, lemmet
#
# 2 vne, overkor, Lob, naclcle, sve, Bmilte, viBe, nolde, berike, nenneB, inen, Bov, ektemenn, Vart, Bkrevet, Majoren, vanne, koran, lielt, anBiktet, Ud, kottet, trem, BZ, Bnakket, vak, overvunnet, ganBke, kare, clem, lutten, nennes, seZ, pilte, cier, KenneB, noldt, dsr, niin, Famle, loran, lekter, zom, bretter, ttun, Ovnene, Btr, Btemme, kraven, kjempende, BlagB, FanF, lubben, degge, synene, denken, Kanß, kjetting, omgav, ite, dirrer, utenkor, IVlen, Bikker, elskeren, ennom, Btod, tangen, Bkritt, avvergende, nand, Btund, Bolen, nder, IvB, dak, Bina, bedrevet, KanB, Bikkert, IvBt, errer, nvite, menß, Btirret, Ze, benkene, mez, lolk, lrem, Evnene, Kvi, kans, mana, lianB, arl, nverandre, KaBtet, knappet, rok, iikk, Btvkke, kvilte, nanden, kulle, lram, riggen, Brien, Blett, raker, fomlet, Bterk, Ivlen
#
# 3 Sinnet, innsmigrende, dinglende, slagg, Eileen, voksent, betagende, gnistrende, skjød, stengelen, spebarn, skuret, nolder, opphisselsen, anonymt, ryddig, uferdig, barskt, barbent, engene, nakent, klebet, måneskinn, nærgående, søylen, Rødt, Værelset, skurrende
#
# 4 lillefingeren, Musklene, tast, tjukke, Sheila, underdanig, hårene, hoven, blusen, Clyde, brystene, svulmende, Austria, herligheten, fyldige, kjemme, fingertuppene, ordens, tinningene, børste, strittet, handflaten, stivhet, Fullstendig, torner, overleppen, bøyet, kvikke
#
# 5 sprekkene, kantinen, bante, ropene, skrikene, idiotiske, naboens, brystvortene, tettet, røken, ekkoet, bebodde, henført, pille, forvridde, dasket, utspilt, fløyet, hård, klasket, spytte, prikket, berøringen, løgnen, anvisninger, øyelokkene, knoklene, fascismen, Zikk, tommelfingeren, hammeren, magasinet, Verten, gnog, skrumpet, gnir, sanseinntrykk, dvele, omrisset, skjules, mumling, sprekke, smekket, Leve, håndflaten, trying, råtner, Viola, nåler, rystende, Hundre, innenfra, Kvinnens
#
# 6 kuppel, luggen, passasje, spøkelser, lyseblå, sitrende, bøtta, hvelvet, Hvite, Leppene, nesebor, skyfri, buer, spiddet, almuen, uvirkelig, tordnet, brystkassen, klippene, nende, dyppet, skuldrer, Brystet, kanoen, granitt, ribbena, øyenbryn
#
# 7 lårene, finger, siddende, stangen, indenfor, Umiddelbart, gennem, vejen, stak, lår, hovedet, Langsomt, hænderne, opad, øjnene, blomsten, skete, pungen, navlen, suge, vej, lem, munden, benene, hoved, trak, nålen
#
# 8 Ask, rap, kvalmende, fyltes, timian, jublende, tomheten, verdensrommet, Sander, ekteskapelig, erindringen, ømhet, distré, dovent, ulvene, oppdagelsen, karet, bedøvet, kones, illusjonen, brisen, tallerkenene, sukkertøy, ulyst, svettet, snufset
#
# 9 bandasjen, festes, formelig, gned, musklene, elegante, overtatt, rekkverket, Pusten, forundre, knaket, krem, Børre, innpå, lungene, smurte, pærer, fristet, skikkelsen, fordypning, svulmet, vinger, stramme, kvasse, ermene, Varmen, plenen, elastiske
#
# 10 barmen, shorts, fettet, skjegg, Håret, mygg, gjenferd, drikken, rødlig, aura, folder, kveldens, gyllen, hake, utslått, dampende, hevelse, skjæret, tinn, bart, omriss, dun, korridor, flakkende, barten, ermer
#
# 11 sanselige, Severin, reflekterte, sprit, giften, lyserød, skjenker, tjern, spinkel, kruset, kannen, lians, sjokkerende, pantsatte, Bloom, bukten, krøller, Utmerket, pantet, arrogante, øyenbrynene, langet, fjære, blondt, vindpust, reflekser, mørkeblå
#
# 12 sloknet, handtrykk, subbet, hotellrom, massivt, uttrykksløst, slukker, Armene, pakistanske, Storbritannias, blodets, mave, slapt, Louisa, Rodney, handledd, Bitter, glat, Lola, unnskyldende, sprikende, nummen, vemmelse, slepende, Wendy, Leah, stolryggen
#
# 13 trestamme, kalv, Belle, bevisstløs, flådd, Duncan, skittent, snytt, selvrespekt, sloss, bjørnen, Publikum, stekt, skinnet, kjennes, inventaret, Pelle, Stan, efterpå, Selger, ekorn, tomat, klippet, låret, jernet, morderen, myste, teltet, svidd, skjortene
#
# 14 strupen, stukket, hoften, vold, skjeden, blodig, bortover, stilte, Vognen, såvidt, fingeren, sådd, stikke, nøye, kalde, innført, skar, sakte, stikkes, kappen, blod, marsjerte, verandaen, unnskyldning, stålet, besluttet, beltet, fullbyrdet, kinnet, kniven, rulle
#
# 15 oppmerksomt, silte, kuler, ryddet, smeltet, Glenn, aper, lempe, Tante, elendig, tyngden, nele, svor, sjanglet, kjøttet, Bertil, skjelvende, hjulene, stinker, innunder, Tårene, hengt, genseren, boblet, temperament, gjentar, ilte, Opp, skrotten
#
# 16 bryster, reisning, hov, aristokratiske, ordrer, kvinnes, blødning, tilbakeholdenhet, fylde, kvinnfolk, majestetisk, blonde, vidunderlig, Merete, peneste, magre, Boris, mannlig, brølte, konstruktiv, gjentatte, brå, slanke, dyttet, nøt, holdningen, lynsnart
#
# 17 vre, muggen, massasje, dødsens, poker, fortsat, piske, svaiet, Føler, stoltheten, mutter, lynte, roterer, underlivet, klø, innvollene, sprøyter, fornemmelser, stjålent, oplevelser, rotere, regjerer, begyndelse, sødme, lava, Bnakke, hæler
#
# 18 sagde, Resten, lidt, fik, vendt, mod, hurtigt, væk, Siden, ind, pengene, gik, Johannes, fremad, faldt, syntes, næsten, grebet, fandt, resultat, søde, Nu, tungt, brutalt, lod, let, hardt, tog, fat
#
# 19 utviklet, stillinger, antall, prosent, forsvarte, innbyggerne, utviklede, klient, antar, Likevel, kalle, lider, ånd, begrepet, tappert, Glem, kaller, linjer, Brage, oppfatning, følelse, mangelfullt, Hver, kledd, engelsk, hendt, dårlig, arret, Pass, gammelt
#
# 20 knokene, heiste, Bjørnen, forrest, demonstrativt, doven, kaminen, avgarde, bydende, frosk, skreket, strakt, glante, ryggraden, Bena, grålysningen, krummet, bedende, flatene, uviss, tomrommet, bremset, gestikulerte, Mira, Crawford, handen, fossil, divanen, ydmykt
#
# 21 tU, bruden, vanvittige, plystre, Vent, nedlatende, Bli, besatt, overvære, strømmet, Linda, KAPITEL, teatret, tent, mottagelse, forrådt, smilet, førestillingen, fortapt, tygget, unngått, Fletcher, fyldig, lærdom, ambassaden, skjærer, bød, vekket, überørt
#
# 22 kvele, tøyet, ballet, kvelende, klamme, kjeven, leggene, glitrer, handkle, vatt, salve, lunken, iskaldt, kodet, pirket, erme, dagligdags, pakkes, mosen, brekker, mane, kilte, Bted, gjennorn, Månen, spares, ekkel
#
# 23 uhørt, individualitet, irriterte, hyler, aftens, skjenke, banner, Mengden, halvannen, skjelte, smigret, Ansvaret, ergret, marinen, forgylte, frydet, korrupsjon, reklamen, raketter, Hector, senator, folde, brett, gammelnorsk, troll, kolossalt, ridende, avhang, mannfolkene
#
# 24 mccl, innbilning, gisp, brønn, fang, plog, snuten, kløften, ksr, svette, neglene, dynen, negler, bitende, spyd, Texas, puten, motforestillinger, elet, jordens, borer, blindt, lommene, bunn, havner, hiver, maven, forover, trøya, bedet, røttene
#
# 25 gjennomskuet, forsvarere, sublime, dyriske, seremoni, ribben, ynkelige, Skuldrene, oversa, rustne, begjæret, vesenet, livstid, kroppene, løvet, Faber, svogeren, groteske, tarvelige, overlegenhet, pip, fortvilte, hofter, lysbilder, borgerkrigen, Bøkene, revy, lidenskaper, enfoldige, skapningen

# %% [markdown]
# # Vekstdiagram
#
# For vekstdiagram brukes kommandoen nb.vekstdiagram().plot(). Input til vekstdiagram er en URN sammen med en liste av ord.

# %%
print(nb.metadata(urns[30]))
nb.plot_sammen_vekst(urns[30], [words,gladord]).plot(figsize=(15,5))
# Out:
# [[2013042408063, 'Croudace, Glynn', 1969, 'Riflen og spydet', 'Bladkompaniet', 'nob', 'eng']]
# C:\Users\larsj\Documents\GitHub\xmining\nbtext.py:1022: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat(rammer)

# %%
nb.plot_sammen_vekst(urns[30],[words, gladord]).plot()

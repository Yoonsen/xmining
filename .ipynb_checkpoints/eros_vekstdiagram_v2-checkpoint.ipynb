# %% [markdown]
# #### Paracode

# %% [markdown]
# Laster ned moduler og filer, `module_update`, `nbtext` og `graph_networkx_louvain`

# %%
! curl -s "https://raw.githubusercontent.com/Yoonsen/Modules/master/module_update.py" > "module_update.py"

# %%
from module_update import update, css, code_toggle, printmd
update('nbtext', overwrite=True)
update('graph_networkx_louvain', overwrite=True)
# Out:
# Updated file `C:\Users\larsj\Documents\GitHub\xmining\nbtext.py`
# Updated file `C:\Users\larsj\Documents\GitHub\xmining\graph_networkx_louvain.py`

# %% [markdown]
# ## Her er noen tilpassede funksjoner

# %% [markdown]
# Aktiver eller fjern `css`

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# Importer moduler

# %%
import nbtext as nb
import graph_networkx_louvain as gnl
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Slår av advarsler fra IPython

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Notebook for erosmining

# %% [markdown]
# Henter URN-er fra fil

# %%
urns = nb.get_urns_from_docx('../Materiale erotisk litteratur 1945-1970 liste 27.09.18.docx')
print('Antall URNer: ', len(urns), urns[:5])
# Out:
# Antall URNer:  456 ['2015090129001', '2011112308125', '2012021608164', '2016111748512', '2010111706020']

# %% [markdown]
# Det kvinnelige materialet

# %%
fem_urns = nb.get_urns_from_docx('../Kvinner Materiale erotisk litteratur 1945-1970 liste  08.02.19.docx')
print("Antall: ", len(fem_urns))
# Out:
# Antall:  39

# %%
# rekonstruerer metadata for URN-ene
meta = [nb.metadata(u) for u in urns]

# %%
# bygger en struktur for å finne frem i metadata

bokinfo = nb.frame([x[0] for x in meta if x != []])
bokinfo.columns = ['urn', 'forfatter', 'år', 'tittel', 'forlag', 'språk', 'trans']
bokinfo.head()
# Out:
#              urn         forfatter      år                    tittel  \
# 0  2015090129001      Mykle, Agnar  1956.0  Sangen om den røde rubin
# 1  2011112308125      Mykle, Agnar  1954.0      Lasso rundt fru Luna
# 2  2012021608164  Aalberse, Han B.  1959.0            Ung kjærlighet
# 3  2016111748512  Aalberse, Han B.  1960.0               Ungt begjær
# 4  2010111706020  Anderberg, Bengt  1949.0                      Kain
#
#       forlag språk trans
# 0  Gyldendal   nob
# 1  Gyldendal   nob
# 2      Atlas   nob   dut
# 3      Atlas   nob   dut
# 4  Bergendal   nob   swe

# %%
# Kommando for å finne bøker, se eksempler under

finn_bok = lambda y, x = 'forfatter': bokinfo[bokinfo[x].str.contains(y)]

# %% [markdown]
# ### Hvordan finne en bok?
#
# Bruk kommandoen `finn_bok('Mykle', 'forfatter')` for å finne alt av Mykle. For å finne en tittel er det bare å legge til 'tittel' som andre parameter `finn_bok('sangen', 'tittel')`. Se eksempler. Parametret 'forfatter' er default, så det kan utelates. Flere eksempler under selve produksjonen av vekstdiagrammer.
#
# For vekstdiagram det bare å kopiere URNen.
#
# Så meta blir: finn_bok, vekstdiagram, finn_bok, vekstdiagram, kanskje en konk innimellom.

# %%
finn_bok('Mykle')
# Out:
#                urn     forfatter      år                     tittel  \
# 0    2015090129001  Mykle, Agnar  1956.0   Sangen om den røde rubin
# 1    2011112308125  Mykle, Agnar  1954.0       Lasso rundt fru Luna
# 83   2011111608114  Mykle, Agnar  1951.0  Tyven, tyven skal du hete
# 105  2015090129001  Mykle, Agnar  1956.0   Sangen om den røde rubin
# 106  2011112308125  Mykle, Agnar  1954.0       Lasso rundt fru Luna
#
#         forlag språk trans
# 0    Gyldendal   nob
# 1    Gyldendal   nob
# 83       Tiden   nob
# 105  Gyldendal   nob
# 106  Gyldendal   nob

# %%
finn_bok('Naken','tittel')
# Out:
#                urn              forfatter      år       tittel  \
# 8    2007051601064  Burroughs, William S.  1968.0  Naken lunsj
# 43   2013080808039       Sandgren, Gustav  1965.0   Naken vind
# 111  2007051601064  Burroughs, William S.  1968.0  Naken lunsj
#
#               forlag språk trans
# 8                Pax   nob   eng
# 43   Alb.Cammermeyer   nob
# 111              Pax   nob   eng

# %%
# Kommando for konkordans, se eksempler nedenfor

konk = lambda word, urns = urns, before = 8, after = 4, size = 2: nb.get_urnkonk(word, {'urns':nb.refine_urn(urns,{'words':[word]} )[:30], 'before':before, 'after':after, 'size':size})

# %% [markdown]
# ### En hurtigversjon av konkordansekommando
#
# Skriv `konk('bryst')` for å undersøke korpuset, URN-ene er allerede fylt inn. Eller bare hoppover. For å se blant URN-er fra kvinner, skriv `konk('bryst', urns=fem_urns)`.

# %%
konk('brystene')
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016030808016?searchText=brystene' target='_blank' style='text-decoration:none'>Franske netter, , 1958</a>
#                 </td>
#                 <td>til ham og omfavnet harn tett , for</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>hennes var blitt like</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016030808016?searchText=brystene' target='_blank' style='text-decoration:none'>Franske netter, , 1958</a>
#                 </td>
#                 <td>i søvn mens kinnene hans fant hvile mellom</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>hennes .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016112148512?searchText=brystene' target='_blank' style='text-decoration:none'>På jakt etter kjærlighet, Friedman, Stuart, 1960</a>
#                 </td>
#                 <td>. Lampen over speilet lyste opp de velformete</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>, og uten å</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016112148512?searchText=brystene' target='_blank' style='text-decoration:none'>På jakt etter kjærlighet, Friedman, Stuart, 1960</a>
#                 </td>
#                 <td>interessert i min figur , ikke formen på</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>mine eller de pene</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015060508197?searchText=brystene' target='_blank' style='text-decoration:none'>Frøknene von Pahlen, Krusenstjerna, Agnes von, 1953</a>
#                 </td>
#                 <td>de veldige lemmene , de svulmende hoftene og</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>, den svære magen</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015060508197?searchText=brystene' target='_blank' style='text-decoration:none'>Frøknene von Pahlen, Krusenstjerna, Agnes von, 1953</a>
#                 </td>
#                 <td>han med små , hissige bevegelser fingret på</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>, kysset han munnen</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015060508197?searchText=brystene' target='_blank' style='text-decoration:none'>Frøknene von Pahlen, Krusenstjerna, Agnes von, 1953</a>
#                 </td>
#                 <td>Silken strammet seg over de høye , spisse</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>. Han strøk fingeren</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015060508197?searchText=brystene' target='_blank' style='text-decoration:none'>Frøknene von Pahlen, Krusenstjerna, Agnes von, 1953</a>
#                 </td>
#                 <td>av noe uhyggelig . Men under de runde</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>hennes lekte den blå</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007030501021?searchText=brystene' target='_blank' style='text-decoration:none'>Slavinnens seier, Lalange, Janet H., 1954</a>
#                 </td>
#                 <td>hennes , og den frie hånden hans kjærtegnet</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>hennes . Hun hadde</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007030501021?searchText=brystene' target='_blank' style='text-decoration:none'>Slavinnens seier, Lalange, Janet H., 1954</a>
#                 </td>
#                 <td>det både naturlig og smigrende da nan blottet</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>hennes og dekket dem</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007030501021?searchText=brystene' target='_blank' style='text-decoration:none'>Slavinnens seier, Lalange, Janet H., 1954</a>
#                 </td>
#                 <td>tanken . For hendene hans søkte allerede etter</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>nenneB . Hun lukket</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007030501021?searchText=brystene' target='_blank' style='text-decoration:none'>Slavinnens seier, Lalange, Janet H., 1954</a>
#                 </td>
#                 <td>Litt etter følte jeg hendene hans famle over</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>mine , hoftene og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007030701025?searchText=brystene' target='_blank' style='text-decoration:none'>Underlig ensomhet, Sollers, Philippe, 1960</a>
#                 </td>
#                 <td>noen hår som hun hadde på spissen av</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>, og ringene under</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011070805079?searchText=brystene' target='_blank' style='text-decoration:none'>Lady Chatterleys elsker, Lawrence, D.H., 1952</a>
#                 </td>
#                 <td>han bare strøk henne lindt over lendene og</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011070805079?searchText=brystene' target='_blank' style='text-decoration:none'>Lady Chatterleys elsker, Lawrence, D.H., 1952</a>
#                 </td>
#                 <td>hennes opp og tilbake helt til han nådde</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>hennes . Han kysset</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011070805079?searchText=brystene' target='_blank' style='text-decoration:none'>Lady Chatterleys elsker, Lawrence, D.H., 1952</a>
#                 </td>
#                 <td>Han lå stille med hånden på</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>hennes . Men hun</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011070805079?searchText=brystene' target='_blank' style='text-decoration:none'>Lady Chatterleys elsker, Lawrence, D.H., 1952</a>
#                 </td>
#                 <td>Han fjernet hånden fra</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>hennes uten å røre</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016112148562?searchText=brystene' target='_blank' style='text-decoration:none'>Hunkatt med svepe, Miller, Wade, 1960</a>
#                 </td>
#                 <td>med armene bak hodet og fin løft på</td>
#                 <td>brystene</td>
#                 <td style='text-align:left'>. Det ene benet</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016112148562?searchText=brystene' target='_blank' style='text-decoration:none'>Hunkatt med sv

# %% [markdown]
# ## Næranalyse av tekst

# %% [markdown]
# En eller flere ordlister for forskjellige formål.

# %% [markdown]
# ### Ordsett for vekstdiagrammer
#
# Har lagt inn dine ordlister. Bare endre på dem, husk å aktiver cellen i så fall. De engelske ordene blir brukt i grafene, som kan være greit.

# %%
eros = """brystene brystet hoften hofter hoftene kjønnet
kyss kysset lemmet lepper leppene låret lår lårene skjød skjødet pikk
pikken fitte fitta pulte puler knulle knullet""".split()
 
care = """hverandre holdt ømt varsomt forsiktig varme varme følelse
følte nærhet nærheten""".split()

brutality = """brutal brutalt voldsom voldsomt ekkel
frastøtende rå voldtekt hensynsløs hensynsløst freste strittet skrek hulket
dyrisk nedverdigende""".split()


tronds = {
    'eros':eros,
    'care':care,
    'brutality':brutality
}

# %% [markdown]
# Sånn ser variabelen ut til slutt:

# %%
tronds
# Out:
# {'eros': ['brystene',
#   'brystet',
#   'hoften',
#   'hofter',
#   'hoftene',
#   'kjønnet',
#   'kyss',
#   'kysset',
#   'lemmet',
#   'lepper',
#   'leppene',
#   'låret',
#   'lår',
#   'lårene',
#   'skjød',
#   'skjødet',
#   'pikk',
#   'pikken',
#   'fitte',
#   'fitta',
#   'pulte',
#   'puler',
#   'knulle',
#   'knullet'],
#  'care': ['hverandre',
#   'holdt',
#   'ømt',
#   'varsomt',
#   'forsiktig',
#   'varme',
#   'varme',
#   'følelse',
#   'følte',
#   'nærhet',
#   'nærheten'],
#  'brutality': ['brutal',
#   'brutalt',
#   'voldsom',
#   'voldsomt',
#   'ekkel',
#   'frastøtende',
#   'rå',
#   'voldtekt',
#   'hensynsløs',
#   'hensynsløst',
#   'freste',
#   'strittet',
#   'skrek',
#   'hulket',
#   'dyrisk',
#   'nedverdigende']}

# %% [markdown]
# # Vekstdiagram

# %%
# Hurtigkommando for å lage plot
# x er en URN, og words er en liste ord, eller et objekt som tronds
import unicodedata
def vekstplot(x, words):
    m = nb.metadata(x)
    nb.plot_sammen_vekst(x,words).plot(figsize = (14,6),title=m[0][1]+' - '+m[0][3] +', ' + str(int(m[0][2])), lw = 4, alpha=0.6);
    title = '_'.join(m[0][1].split())+'-'+'_'.join(m[0][3].split())+'-'+ str(m[0][2])+'.jpg'
    title = unicodedata.normalize('NFKD', title).encode('ascii','ignore').decode('utf-8')
    plt.savefig(title, dpi=300)

# %% [markdown]
# Starter med å finne alle bøkene av Agnar Mykle:

# %%
finn_bok('Mykle')
# Out:
#                urn     forfatter      år                     tittel  \
# 0    2015090129001  Mykle, Agnar  1956.0   Sangen om den røde rubin
# 1    2011112308125  Mykle, Agnar  1954.0       Lasso rundt fru Luna
# 83   2011111608114  Mykle, Agnar  1951.0  Tyven, tyven skal du hete
# 105  2015090129001  Mykle, Agnar  1956.0   Sangen om den røde rubin
# 106  2011112308125  Mykle, Agnar  1954.0       Lasso rundt fru Luna
#
#         forlag språk trans
# 0    Gyldendal   nob
# 1    Gyldendal   nob
# 83       Tiden   nob
# 105  Gyldendal   nob
# 106  Gyldendal   nob

# %% [markdown]
# Kopierer URN-en for rubinen, og plotter med ordene i `tronds`. Boktittel og forfatter kommer opp i diagramtittelen.

# %%
vekstplot(2015090129001, tronds);

# %%
vekstplot(2011112308125,tronds);

# %%
finn_bok('Bjørg')
# Out:
#                urn   forfatter      år              tittel    forlag språk  \
# 30   2007072501029  Vik, Bjørg  1970.0   Gråt elskede mann  Cappelen   nob
# 37   2007050401037  Vik, Bjørg  1968.0  Det grådige hjerte  Cappelen   nob
# 128  2007072501029  Vik, Bjørg  1970.0   Gråt elskede mann  Cappelen   nob
# 173  2007072501029  Vik, Bjørg  1970.0   Gråt elskede mann  Cappelen   nob
#
#     trans
# 30
# 37
# 128
# 173

# %%
vekstplot(2007072501029, tronds)

# %%
vekstplot(2007050401037, tronds)

# %%
finn_bok('Masterson')
# Out:
#                urn         forfatter      år        tittel         forlag  \
# 6    2013042338044  Masterson, Louis  1967.0   rangers ære  Bladkompaniet
# 29   2013053008119  Masterson, Louis  1970.0  Dødsklokkene  Bladkompaniet
# 84   2013053008089  Masterson, Louis  1969.0       Apache!  Bladkompaniet
# 85   2013053008091  Masterson, Louis  1969.0  Blod og gull  Bladkompaniet
# 86   2013042508137  Masterson, Louis  1969.0     Coyotéros  Bladkompaniet
# 109  2013042338044  Masterson, Louis  1967.0   rangers ære  Bladkompaniet
# 127  2013053008119  Masterson, Louis  1970.0  Dødsklokkene  Bladkompaniet
#
#     språk trans
# 6     nob
# 29    nob
# 84    nob
# 85    nob
# 86    nob
# 109   nob
# 127   nob

# %%
vekstplot(2013042508137,tronds)

# %%
vekstplot(2013053008089,tronds)

# %%
vekstplot(2013053008119,tronds)

# %%
finn_bok('ung','tittel')
# Out:
#                urn       forfatter      år            tittel     forlag språk  \
# 150  2011120208258  Halevy, Julian  1956.0  De unge elskende  Gyldendal   nob
# 221  2011120208258  Halevy, Julian  1956.0  De unge elskende  Gyldendal   nob
#
#     trans
# 150   eng
# 221   eng

# %%
vekstplot(2011120208258,tronds)

# %% [markdown]
# URNene finner du ved å bruke `finn_bok` som i et par celler over.

# %%
finn_bok('Bladkompaniet', 'forlag')
# Out:
#                urn             forfatter      år  \
# 6    2013042338044      Masterson, Louis  1967.0
# 10   2013041908081      Spillane, Mickey  1967.0
# 23   2013042908119       Wallace, Irving  1968.0
# 24   2013042408063       Croudace, Glynn  1969.0
# 25   2013050208016       Croudace, Glynn  1969.0
# 26   2013052908048       Croudace, Glynn  1969.0
# 28   2013052908049       Collins, Jackie  1969.0
# 29   2013053008119      Masterson, Louis  1970.0
# 38   2013041908061                        1969.0
# 49   2013041908041    MacDonald, John D.  1958.0
# 51   2011112308039      Sandgren, Gustav  1954.0
# 52   2013042408065           Bates, H.E.  1964.0
# 74   2013042408073       Kozol, Jonathan  1965.0
# 76   2013042508081     Kauffman, Stanley  1959.0
# 84   2013053008089      Masterson, Louis  1969.0
# 85   2013053008091      Masterson, Louis  1969.0
# 86   2013042508137      Masterson, Louis  1969.0
# 89   2013041908070    MacDonald, John D.  1953.0
# 90   2013041908059          Harvey, John  1963.0
# 109  2013042338044      Masterson, Louis  1967.0
# 113  2013041908081      Spillane, Mickey  1967.0
# 124  2013042908119       Wallace, Irving  1968.0
# 126  2013052908049       Collins, Jackie  1969.0
# 127  2013053008119      Masterson, Louis  1970.0
# 190  2013050208016       Croudace, Glynn  1969.0
# 191  2013041908041    MacDonald, John D.  1958.0
# 198  2013042508013       Trolle, Elsa af  1953.0
# 204  2013042508010       Pratt, Theodore  1953.0
# 205  2013042408074       Prévost, Marcel  1952.0
# 211  2013042338088     Casanova, Giacomo  1954.0
# 224  2013041608017  Glendinning, Richard  1958.0
# 241  2013042408069           Weil, Jerry  1965.0
# 243  2013041908157     Raphael, Frederic  1967.0
# 246  2013041608006       Mair, George B.  1967.0
# 247  2013042508122                        1967.0
# 248  2013041908176       Connell, Vivian  1967.0
# 249  2013041908060          Beaty, David  1968.0
# 251  2013041608024       St. John, David  1969.0
# 254  2013060408147   Brett, John Michael  1969.0
#
#                            tittel         forlag språk trans
# 6                     rangers ære  Bladkompaniet   nob
# 10                 Med kaldt blod  Bladkompaniet   nob   eng
# 23                 Feber i blodet  Bladkompaniet   nob   eng
# 24               Riflen og spydet  Bladkompaniet   nob   eng
# 25                Den Svarte rose  Bladkompaniet   nob   eng
# 26                   Afrikas blod  Bladkompaniet   nob   eng
# 28   Verden er full av gifte menn  Bladkompaniet   nob   eng
# 29                   Dødsklokkene  Bladkompaniet   nob
# 38               Norsk Decamerone  Bladkompaniet   nob
# 49                     Het sommer  Bladkompaniet   nob   eng
# 51                  Livet er rikt  Bladkompaniet   nob   swe
# 52                    Brudekronen  Bladkompaniet   nob   eng
# 74                      søte gift  Bladkompaniet   nob   eng
# 76                  farlige leken  Bladkompaniet   nob
# 84                        Apache!  Bladkompaniet   nob
# 85                   Blod og gull  Bladkompaniet   nob
# 86                      Coyotéros  Bladkompaniet   nob
# 89                    De fordømte  Bladkompaniet   nob   eng
# 90                     En å elske  Bladkompaniet   nob   eng
# 109                   rangers ære  Bladkompaniet   nob
# 113                Med kaldt blod  Bladkompaniet   nob   eng
# 124                Feber i blodet  Bladkompaniet   nob   eng
# 126  Verden er full av gifte menn  Bladkompaniet   nob   eng
# 127                  Dødsklokkene  Bladkompaniet   nob
# 190               Den Svarte rose  Bladkompaniet   nob   eng
# 191                    Het sommer  Bladkompaniet   nob   eng
# 198                 Livets flamme  Bladkompaniet   nob   swe
# 204                       Kokotte  Bladkompaniet   nob   eng
# 205                 Syndig uskyld  Bladkompaniet   nob   fre
# 211  Casanovas kjærlighetseventyr  Bladkompaniet   nob   ita
# 224                   Sirkuspiken  Bladkompaniet   nob   eng
# 241                  Uro i blodet  Bladkompaniet   nob   eng
# 243                       Darling  Bladkompaniet   nob   eng
# 246              Lev, elsk og dø!  Bladkompaniet   nob   eng
# 247               Piken på bussen  Bladkompaniet   nob   eng
# 248             Livet på solsiden  Bladkompaniet   nob   eng
# 249           Kjærligheten lokker  Bladkompaniet   nob   eng
# 251              Mannen fra C.I.A  Bladkompaniet   nob   eng
# 254            Hakekorsets skygge  Bladkompaniet   nob   eng

# %%
vekstplot(2013041908081, tronds)

# %%
vekstplot(2013041608006, tronds)

# %%
vekstplot(2013042508081, tronds)
